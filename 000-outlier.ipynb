# %%
import pandas as pd
import numpy as np
import time
import datetime
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from collections import Counter

# %%
data = pd.read_csv('./data/round1_ijcai_18_train_20180301.txt', sep=' ', encoding='utf-8')
data.head()
# Out:
#            instance_id              item_id  \
# 0   108641074714126964  3412720377098676069
# 1  5754713551599725161  3412720377098676069
# 2   842679481291040981  3412720377098676069
# 3   937088850059189027  3412720377098676069
# 4  7975697065017708072  3412720377098676069
#
#                         item_category_list  \
# 0  7908382889764677758;5799347067982556520
# 1  7908382889764677758;5799347067982556520
# 2  7908382889764677758;5799347067982556520
# 3  7908382889764677758;5799347067982556520
# 4  7908382889764677758;5799347067982556520
#
#                                   item_property_list        item_brand_id  \
# 0  2072967855524022579;5131280576272319091;263639...  1975590437749032870
# 1  2072967855524022579;5131280576272319091;263639...  1975590437749032870
# 2  2072967855524022579;5131280576272319091;263639...  1975590437749032870
# 3  2072967855524022579;5131280576272319091;263639...  1975590437749032870
# ...

# %%
data.drop_duplicates(inplace=True)

# %%
items = data.item_id
items_counter = Counter()
for item in items:
    if item in items_counter:
        items_counter[item] += 1
    else:
        items_counter[item] = 1

# %%
for item in items_counter:
    print(item, items_counter[item])
# Out:
# 3412720377098676069 20
# 285660928590172217 64
# 5202355029344881809 76
# 4596211878136725009 6
# 8626373102868398325 7
# 3586219554105453016 3
# 6753712242116121802 2
# 8237485728010278787 11
# 6032712367823716409 260
# 8629327205974770664 500
# 919980016657888153 823
# 3079313931663066657 96
# 379848927776544534 313
# 1988826649999608740 480
# 2540781378235236842 551
# 7252664911628293109 451
# 1093710751022752245 803
# 2349124492995958413 1403
# 4684989551642457113 277
# 8238195786294017989 544
# 557883074900282934 662
# 7775860457160940180 60
# 8996223722581518529 149
# 8824610546121211352 687
# 2127588125899824865 498
# 1519543411555287447 297
# 8574382974114632001 291
# 3546971049578000080 100
# 2378909420050091061 238
# 4215883534709645310 528
# 2854920230169118186 572
# 7936816669162499916 233
# 2271322547559236386 152
# 86163586190489549 10
# 8553960424035984421 115
# 4946998684303255721 4
# 5035130708911592193 1
# 1480206973548816689 168
# 7849453275941597478 24
# ...

# %%
items_counter.most_common(200)
# Out:
# [(7571023501622243456, 3000),
#  (2986722878397696833, 2836),
#  (5410526681843914464, 2578),
#  (2079092401639430105, 2513),
#  (2709839111509701702, 2448),
#  (5716046650492250518, 2267),
#  (5467735841796001072, 2258),
#  (2723541945574109807, 2021),
#  (3444647220397515150, 1937),
#  (4817583173619024436, 1919),
#  (4162406225225963765, 1780),
#  (7937690818610877888, 1683),
#  (8970449145125394567, 1631),
#  (534920639711707822, 1608),
#  (751443051994527892, 1596),
#  (671302156973073367, 1591),
#  (5634978682268415449, 1571),
#  (5586531724608162781, 1528),
#  (2349124492995958413, 1403),
#  (2530039332833674681, 1397),
#  (509936336103770855, 1394),
#  (5088920748697829728, 1377),
#  (4885486757349832183, 1368),
#  (3401173841796395052, 1339),
#  (4429962171977692955, 1321),
#  (7697581527441910922, 1260),
#  (8906948455106358440, 1249),
#  (8961114074287787809, 1245),
#  (6335890202072992021, 1219),
#  (7085665113142227362, 1197),
#  (8777881594532200391, 1174),
# ...

# %%
len(instance.unique())
# Out:
# 478087

# %%
len(data)
# Out:
# 478111
