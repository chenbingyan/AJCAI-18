# %%
import pandas as pd

# %%
result = pd.read_csv('./result4_7.csv', sep=' ', encoding='utf-8')
result.head()
# Out:
#            instance_id  predicted_score
# 0  2475218615076601065         0.017775
# 1   398316874173557226         0.020633
# 2  6586402638209028583         0.035750
# 3  1040996105851528465         0.049197
# 4  6316278569655873454         0.030657

# %%
result.sort_values(by=['predicted_score'], ascending=False)
# Out:
#                instance_id  predicted_score
# 15351  2529902529148693588         0.404345
# 16564  2986324117662229566         0.404256
# 10068  1010269937417460583         0.375354
# 625    1096101093776493333         0.353111
# 14331  4656683695747485899         0.346530
# 2364   5469336665067176723         0.337191
# 7733   3578870785311684191         0.327748
# 14822     9191324088377216         0.324442
# 8673   1926559934818125488         0.311897
# 6590   4319482925340332048         0.304023
# 18139  3529100366943979412         0.301246
# 16291  3539312684586869491         0.294214
# 5329   6892137978072134489         0.278769
# 4539   6463650623078897177         0.273156
# 13370  6610712333086578507         0.272904
# 12654  2757885256855822021         0.264347
# 4898    700854356772106662         0.261547
# 2753   3843848757289475763         0.254195
# 17352  2548848014524362033         0.250545
# 6418   7585989089284727879         0.247570
# ...

# %%
result = pd.read_csv('./result4_5_0.0836.csv', sep=' ', encoding='utf-8')
result = result.sort_values(by=['predicted_score'], ascending=False)
result
# Out:
#                instance_id  predicted_score
# 12854  1868998071342352601         0.195448
# 8387   5928474156086467037         0.166189
# 11052  1775981491450157644         0.165246
# 4539   6463650623078897177         0.161938
# 13707  2709798788325671180         0.160327
# 4537   8741553381203760669         0.160083
# 3841   1407850874073626617         0.157700
# 4535   7331939847687738933         0.156213
# 2469   2490893592561535442         0.151826
# 18248  8172244732086270700         0.149737
# 2471   7420821991863772046         0.148429
# 2474   1959058443017439812         0.147783
# 15165  5760081535319429247         0.146161
# 4178   7329572048254981959         0.144066
# 17583  3734861946527852065         0.143902
# 12158   157934202434496433         0.143168
# 13696   100197553740233585         0.142938
# 4538   6051718072326462243         0.139422
# 8548   1754616850579145963         0.138407
# 2476   4676624139580120112         0.138201
# ...
